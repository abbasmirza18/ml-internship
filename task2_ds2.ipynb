# %% [markdown]
# <a href="https://colab.research.google.com/github/abbasmirza18/ml-internship/blob/main/task2_ds2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/Electric_Vehicle_Population_Data.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43609 entries, 0 to 43608
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   VIN (1-10)                                         43609 non-null  object
#  1   County                                             43608 non-null  object
#  2   City                                               43608 non-null  object
#  3   State                                              43609 non-null  object
#  4   Postal Code                                        43608 non-null  float64
#  5   Model Year                                         43609 non-null  int64
#  6   Make                                               43609 non-null  object
#  7   Model                                              43609 non-null  object
#  8   Electric Vehicle Type                              43609 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  43609 non-null  object
#  10  Electric Range                                     43609 non-null  int64
#  11  Base MSRP                                          43609 non-null  int64
#  12  Legislative District                               43608 non-null  float64
#  13  DOL Vehicle ID                                     43609 non-null  int64
#  14  Vehicle Location                                   43608 non-null  object
#  15  Electric Utility                                   43608 non-null  object
#  16  2020 Census Tract                                  43607 non-null  float64
# dtypes: float64(3), int64(4), object(10)
# memory usage: 5.7+ MB

# %% [markdown]
# Univariate Analysis

# %% [markdown]
# Uni means single and variate means variable. Hence univariate means the analysis of a single variable. In univariate analysis, we are trying to analyse the pattern present in a single variable.
#
# Histogram: Histogram is used to plot the graphical representation of a numerical variable. The x-axis represents the numeric data and y-axis represents the respective count of the data.

# %%
import matplotlib.pyplot as plt
plt.hist(data["Electric Range"])           # Histogram plot using matplotlib
plt.xlabel("Electric Range")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
import matplotlib.pyplot as plt
plt.hist(data["Base MSRP"])           # Histogram plot using matplotlib
plt.xlabel("Base MSRP")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Box plot: Box plot is created to get the summary of variable ie. minimum, first quartile, median, 3rd quartile and maximum.

# %%
plt.boxplot(data["Electric Range"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7a81ae494130>,
#   <matplotlib.lines.Line2D at 0x7a81ae4943d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7a81ae494670>,
#   <matplotlib.lines.Line2D at 0x7a81ae494910>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7a81ae46be50>],
#  'medians': [<matplotlib.lines.Line2D at 0x7a81ae494bb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7a81ae494e50>],
#  'means': []}

# %% [markdown]
# Univariate Analysis for Categorical Variables

# %%
data = data.head(5)
sns.countplot(data, x="Make")
# Out:
# <Axes: xlabel='Make', ylabel='count'>

# %% [markdown]
# tesla is the top maker

# %%
# Pie chart using matplotlib
data = data.head(5)
Make = data['Make'].value_counts()
plt.pie(Make.values, labels=Make.index, autopct='%1.1f%%')
plt.title("Make Distribution")
# Out:
# Text(0.5, 1.0, 'Make Distribution')

# %% [markdown]
# **BIVARIATE ANALYSIS**

# %%
# Scatter plot using Seaborn
sns.scatterplot(data, x="County", y="Make")
plt.title("Scatter Plot of county vs make")
plt.xlabel("county")
plt.ylabel("make")
# Out:
# Text(0, 0.5, 'make')

# %%
sns.countplot(data, x="County", hue="Make")
# Out:
# <Axes: xlabel='County', ylabel='count'>

# %%
sns.countplot(data, x="County", hue="Model")
# Out:
# <Axes: xlabel='County', ylabel='count'>

# %%
sns.barplot(data, x="Electric Range", y="Make")
# Out:
# <Axes: xlabel='Electric Range', ylabel='Make'>

# %%
data = data.head(5)
sns.countplot(data, x="Electric Vehicle Type")
# Out:
# <Axes: xlabel='Electric Vehicle Type', ylabel='count'>

# %%
# Pie chart using matplotlib
data = data.head(5)
City = data['City'].value_counts()
plt.pie(City.values, labels=City.index, autopct='%1.1f%%')
plt.title("City Distribution")
# Out:
# Text(0.5, 1.0, 'City Distribution')
