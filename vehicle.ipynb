# %% [markdown]
# <a href="https://colab.research.google.com/github/abbasmirza18/ml-internship/blob/main/vehicle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd

# %%
df = pd.read_csv("/content/Electric_Vehicle_Population_Data.csv")

# %%
df.head(1) #The command `df.head(1)` in Python Pandas displays the first row of the DataFrame 'df'.
# Out:
#    VIN (1-10)    County   City State  Postal Code  Model Year   Make    Model  \
# 0  5YJYGDEF5L  Thurston  Lacey    WA      98516.0        2020  TESLA  MODEL Y
#
#             Electric Vehicle Type  \
# 0  Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             291
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  22.0       124535071
#
#                   Vehicle Location        Electric Utility  2020 Census Tract
# 0  POINT (-122.7474291 47.0821119)  PUGET SOUND ENERGY INC       5.306701e+10

# %% [markdown]
# The command `df.head()` in Python Pandas is used to display the first five rows of the DataFrame 'df' for a quick overview of its structure and data.

# %%
df.head()
# Out:
#    VIN (1-10)    County       City State  Postal Code  Model Year    Make  \
# 0  5YJYGDEF5L  Thurston      Lacey    WA      98516.0        2020   TESLA
# 1  1N4BZ1CP1K      King  Sammamish    WA      98074.0        2019  NISSAN
# 2  5YJXCDE28G      King       Kent    WA      98031.0        2016   TESLA
# 3  JHMZC5F37M    Kitsap    Poulsbo    WA      98370.0        2021   HONDA
# 4  WA1F2AFY4P  Thurston    Olympia    WA      98501.0        2023    AUDI
#
#      Model                   Electric Vehicle Type  \
# 0  MODEL Y          Battery Electric Vehicle (BEV)
# 1     LEAF          Battery Electric Vehicle (BEV)
# 2  MODEL X          Battery Electric Vehicle (BEV)
# 3  CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 4     Q5 E  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             291
# 1           Clean Alternative Fuel Vehicle Eligible             150
# ...

# %% [markdown]
# The command `df.tail()` in Python Pandas is used to display the last five rows of the DataFrame 'df', providing a quick overview of the dataset's concluding rows.

# %%
df.tail()
# Out:
#        VIN (1-10)     County         City State  Postal Code  Model Year  \
# 30523  1N4AZ1CP6J       King      Seattle    WA      98115.0        2018
# 30524  WBY1Z4C50F   Thurston      Olympia    WA      98501.0        2015
# 30525  7SAYGAEE9P  Snohomish     Lynnwood    WA      98037.0        2023
# 30526  5YJYGDEFXL       King      Seattle    WA      98126.0        2020
# 30527  YV4H60CL8N       King  Federal Way    WA      98023.0        2022
#
#          Make    Model                   Electric Vehicle Type  \
# 30523  NISSAN     LEAF          Battery Electric Vehicle (BEV)
# 30524     BMW       I3  Plug-in Hybrid Electric Vehicle (PHEV)
# 30525   TESLA  MODEL Y          Battery Electric Vehicle (BEV)
# 30526   TESLA  MODEL Y          Battery Electric Vehicle (BEV)
# 30527   VOLVO     XC90  Plug-in Hybrid Electric Vehicle (PHEV)
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# ...

# %% [markdown]
# The command `df.columns` in Python Pandas is used to retrieve and display the column names of the DataFrame 'df', offering a quick way to inspect the available columns in the dataset.

# %%
df.columns # Just to show the column names
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %% [markdown]
# The command `Car_Popularity = df.value_counts(["Make", "Model"], ascending=True)` in Python Pandas generates a DataFrame called `Car_Popularity` that contains the counts of unique combinations of "Make" and "Model" in the original DataFrame 'df'. The counts are sorted in ascending order, providing a view of the popularity of different car makes and models based on the dataset.

# %%
Car_Popularity = df.value_counts(["Make","Model"],ascending=True)

# %%
Car_Popularity
# Out:
# Make                  Model
# WHEEGO ELECTRIC CARS  WHEEGO            1
# TH!NK                 CITY              1
# AUDI                  A8 E              1
# RIVIAN                EDV               1
# LAND ROVER            RANGE ROVER       1
#                                      ...
# CHEVROLET             BOLT EV        1098
# TESLA                 MODEL S        1348
# NISSAN                LEAF           2504
# TESLA                 MODEL 3        5723
#                       MODEL Y        6129
# Length: 124, dtype: int64

# %% [markdown]
# The command `Car_Popularity.tail(10).plot(kind='barh', title='Car Model Popularity Graph', figsize=(20,10), ylabel="TOP 10 POPULAR MODELS", xlabel="Total number of cars", fontsize=15)` in Python utilizes the Pandas DataFrame `Car_Popularity` to create a horizontal bar chart representing the popularity of the top 10 car models. The chart is customized with a specified title, labels for the y-axis and x-axis, a defined figure size, and a specified font size for enhanced visualization. The data used for plotting is derived from the tail (bottom) of the `Car_Popularity` DataFrame, indicating the least popular car models in the dataset.

# %%
Car_Popularity.tail(10).plot(kind='barh',title = 'Car Model Popularity Graph',figsize=(20,10), ylabel = "TOP 10 POPULAR MODELS", xlabel = "Total number of cars", fontsize = 15)
# Out:
# <Axes: title={'center': 'Car Model Popularity Graph'}, xlabel='Total number of cars', ylabel='TOP 10 POPULAR MODELS'>

# %% [markdown]
# The command `Company_Popularity.tail(10).plot(kind='barh', title='Company Popularity Graph', figsize=(20, 10), fontsize=15, ylabel="TOP 10 Popular Companies", xlabel="Total number of cars")` in Python uses a Pandas DataFrame named `Company_Popularity` to create a horizontal bar chart. The chart represents the popularity of the top 10 companies based on the total number of cars associated with each company. Customizations include a specified title, labels for the y-axis and x-axis, a defined figure size, and a specified font size for improved readability. The data used for plotting is derived from the least popular companies, as indicated by the tail (bottom) of the `Company_Popularity` DataFrame.

# %%
Company_Popularity.tail(10).plot(kind='barh', title = 'Company Popularity Graph',figsize=(20,10),fontsize = 15, ylabel = "TOP 10 Popular Companies", xlabel = "Total number of cars")
# Out:
# <Axes: title={'center': 'Company Popularity Graph'}, xlabel='Total number of cars', ylabel='TOP 10 Popular Companies'>

# %% [markdown]
# ## **Lets see which County has more cars**
# The command `CarsPerCounty.tail(10).plot(kind='barh', title='Cars Per County Graph', figsize=(15, 10), fontsize=15, ylabel="County", xlabel="Total number of cars")` in Python utilizes a Pandas DataFrame named `CarsPerCounty` to create a horizontal bar chart. The chart illustrates the distribution of the total number of cars across the top 10 counties, with customizations such as a specified title, labels for the y-axis and x-axis, a defined figure size, and a specified font size for better presentation. The data used for plotting is derived from the tail (bottom) of the `CarsPerCounty` DataFrame, indicating the least represented counties in terms of car numbers.

# %%
CarsPerCounty = df.value_counts(["County"],ascending=True)

# %%
CarsPerCounty.tail(10).plot(kind='barh', title = 'Cars Per County Graph',figsize=(15,10),fontsize = 15, ylabel = "County", xlabel = "Total number of cars")
# Out:
# <Axes: title={'center': 'Cars Per County Graph'}, xlabel='Total number of cars', ylabel='County'>

# %% [markdown]
# ## **Lets see which City has the most cars**
# The command `CarsPerCity.tail(10).plot(kind='barh', title='Cars Per City Graph', figsize=(15, 10), fontsize=15, ylabel="City", xlabel="Total number of cars")` in Python uses a Pandas DataFrame named `CarsPerCity` to create a horizontal bar chart. The chart visualizes the distribution of the total number of cars across the top 10 cities, with customizations including a specified title, labels for the y-axis and x-axis, a defined figure size, and a specified font size for improved readability. The data used for plotting is derived from the least represented cities, as indicated by the tail (bottom) of the `CarsPerCity` DataFrame.

# %%
CarsPerCity = df.value_counts(["City"],ascending = True)

# %%
CarsPerCity.tail(10).plot(kind='barh', title = 'Cars Per City Graph',figsize=(15,10),fontsize = 15, ylabel = "City", xlabel = "Total number of cars")
# Out:
# <Axes: title={'center': 'Cars Per City Graph'}, xlabel='Total number of cars', ylabel='City'>

# %% [markdown]
# # **Lets see which county and city has the more cars**
# The command `CarsPerCityandCounty.tail(10).plot(kind='barh', title='Cars Per City and County Graph', figsize=(15, 10), fontsize=15, ylabel="City and County", xlabel="Total number of cars")` in Python utilizes a Pandas DataFrame named `CarsPerCityandCounty` to create a horizontal bar chart. This chart visualizes the distribution of the total number of cars across the top 10 combinations of cities and counties. Customizations include a specified title, labels for the y-axis and x-axis, a defined figure size, and a specified font size for enhanced readability. The data used for plotting is derived from the least represented city-county combinations, as indicated by the tail (bottom) of the `CarsPerCityandCounty` DataFrame.

# %%
CarsPerCityandCounty = df.value_counts(["City","County"],ascending = True)

# %%
CarsPerCityandCounty.tail(10).plot(kind='barh', title = 'Cars Per City and County Graph',figsize=(15,10),fontsize = 15, ylabel = "City and County", xlabel = "Total number of cars")
# Out:
# <Axes: title={'center': 'Cars Per City and County Graph'}, xlabel='Total number of cars', ylabel='City and County'>

# %% [markdown]
# ### **Tesla is the clear winner and Kings county has the most wealth as it has the highest ratio of the electric cars.**
